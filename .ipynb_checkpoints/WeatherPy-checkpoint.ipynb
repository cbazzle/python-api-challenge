# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key

from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = 'output_data_cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# # Perform API Calls

# %%
#Perform a weather check on each city using a series of successive API calls.
city_df = []
record = 0
count = 1

print('Beginning Data Retrieval')
print('------------------------')

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"
query_url = f"{url}appid={api_key}&q="

for city in cities:

    # Get weather data
    try:
        response = requests.get(query_url + city).json()
        
        country = response['sys']['country']
        lat = response['coord']['lat']
        long = response['coord']['lon']
        temp = response['main']['temp_max']
        wind = response['wind']['speed']
        clouds = response['clouds']['all']
        humidity = response['main']['humidity']
        datetime = response['dt']
        
        city_df.append({'City': city,
                            'Country': country,
                            'Lat': lat,
                            'Lng': long,
                            'Max Temp': temp,
                            'Wind Speed': wind,
                            'Cloudiness': clouds,
                            'Humidity': humidity,
                            'Date': datetime})
    
        if record == 50:
            record = 1
            count += 1
        else:
            record += 1
            
        print(f'Processing Record {record} of Set {count}|{city}')
        time.sleep(1.01)
           
    except:
        print('City not found. Skipping...')
        pass
        time.sleep(1.01)
        
print('------------------------')
print('-Data Retrieval Complete')
print('------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1|ribeira grande
# Processing Record 2 of Set 1|gunupur
# Processing Record 3 of Set 1|rikitea
# Processing Record 4 of Set 1|isangel
# Processing Record 5 of Set 1|geraldton
# Processing Record 6 of Set 1|kodiak
# Processing Record 7 of Set 1|bluff
# Processing Record 8 of Set 1|atuona
# Processing Record 9 of Set 1|tiksi
# Processing Record 10 of Set 1|constitucion
# Processing Record 11 of Set 1|hobart
# City not found. Skipping...
# Processing Record 12 of Set 1|shimoda
# Processing Record 13 of Set 1|fortuna
# Processing Record 14 of Set 1|saint-philippe
# Processing Record 15 of Set 1|kargasok
# Processing Record 16 of Set 1|iqaluit
# Processing Record 17 of Set 1|brae
# Processing Record 18 of Set 1|port alfred
# Processing Record 19 of Set 1|longyearbyen
# Processing Record 20 of Set 1|araouane
# City not found. Skipping...
# Processing Record 21 of Set 1|rosetta
# Processing Record 22 of Set 1|nelson bay
# Processing Record 23 of Set 1|hermanus
# Processing Record 24 of Set 1|cape town
# Processing Record 25 of Set 1|ushuaia
# Processing Record 26 of Set 1|east london
# City not found. Skipping...
# Processing Record 27 of Set 1|mataura
# Processing Record 28 of Set 1|vorkuta
# Processing Record 29 of Set 1|griffith
# City not found. Skipping...
# Processing Record 30 of Set 1|puerto ayacucho
# Processing Record 31 of Set 1|keuruu
# Processing Record 32 of Set 1|ostrovnoy
# Processing Record 33 of Set 1|puerto ayora
# Processing Record 34 of Set 1|lasa
# Processing Record 35 of Set 1|shonguy
# Processing Record 36 of Set 1|pisco
# City not found. Skipping...
# Processing Record 37 of Set 1|mombasa
# Processing Record 38 of Set 1|rosehearty
# City not found. Skipping...
# Processing Record 39 of Set 1|chokurdakh
# Processing Record 40 of Set 1|alta floresta
# Processing Record 41 of Set 1|maceio
# Processing Record 42 of Set 1|adrar
# Processing Record 43 of Set 1|kudahuvadhoo
# Processing Record 44 of Set 1|puerto escondido
# Processing Record 45 of Set 1|nokaneng
# City not found. Skipping...
# Processing Record 46 of Set 1|magadan
# Processing Record 47 of Set 1|busselton
# Processing Record 48 of Set 1|novyy urengoy
# Processing Record 49 of Set 1|kapit
# Processing Record 50 of Set 1|ancud
# Processing Record 1 of Set 2|kovdor
# Processing Record 2 of Set 2|hilo
# Processing Record 3 of Set 2|mahebourg
# Processing Record 4 of Set 2|portland
# Processing Record 5 of Set 2|bathsheba
# Processing Record 6 of Set 2|asau
# Processing Record 7 of Set 2|khatanga
# Processing Record 8 of Set 2|chum phae
# Processing Record 9 of Set 2|yellowknife
# Processing Record 10 of Set 2|thompson
# Processing Record 11 of Set 2|megion
# City not found. Skipping...
# Processing Record 12 of Set 2|necochea
# Processing Record 13 of Set 2|monrovia
# Processing Record 14 of Set 2|lakselv
# Processing Record 15 of Set 2|ponta do sol
# Processing Record 16 of Set 2|komsomolskiy
# Processing Record 17 of Set 2|albany
# Processing Record 18 of Set 2|avarua
# Processing Record 19 of Set 2|kaitangata
# Processing Record 20 of Set 2|tukrah
# Processing Record 21 of Set 2|coquimbo
# Processing Record 22 of Set 2|kapaa
# City not found. Skipping...
# Processing Record 23 of Set 2|severo-kurilsk
# Processing Record 24 of Set 2|tuktoyaktuk
# Processing Record 25 of Set 2|kutum
# Processing Record 26 of Set 2|mahibadhoo
# Processing Record 27 of Set 2|castro
# City not found. Skipping...
# Processing Record 28 of Set 2|clyde river
# Processing Record 29 of Set 2|katsuura
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 2|luba
# Processing Record 31 of Set 2|vaini
# Processing Record 32 of Set 2|pacific grove
# Processing Record 33 of Set 2|vila franca do campo
# Processing Record 34 of Set 2|los llanos de aridane
# Processing Record 35 of Set 2|kavaratti
# Processing Record 36 of Set 2|avera
# Processing Record 37 of Set 2|puerto carreno
# Processing Record 38 of Set 2|cockburn town
# Processing Record 39 of Set 2|hami
# Processing Record 40 of Set 2|hasaki
# Processing Record 41 of Set 2|butaritari
# Processing Record 42 of Set 2|coxim
# Processing Record 43 of Set 2|trinidad
# Processing Record 44 of Set 2|leeston
# Processing Record 45 of Set 2|vestmannaeyjar
# Processing Record 46 of Set 2|namibe
# Processing Record 47 of Set 2|hostotipaquillo
# Processing Record 48 of Set 2|boende
# Processing Record 49 of Set 2|hofn
# Processing Record 50 of Set 2|thinadhoo
# Processing Record 1 of Set 3|cururupu
# Processing Record 2 of Set 3|mayo
# Processing Record 3 of Set 3|jardim
# Processing Record 4 of Set 3|port macquarie
# Processing Record 5 of Set 3|half moon bay
# City not found. Skipping...
# Processing Record 6 of Set 3|new norfolk
# Processing Record 7 of Set 3|punta arenas
# Processing Record 8 of Set 3|kalmunai
# Processing Record 9 of Set 3|nikolskoye
# Processing Record 10 of Set 3|papara
# Processing Record 11 of Set 3|bredasdorp
# Processing Record 12 of Set 3|ipoh
# Processing Record 13 of Set 3|khuzdar
# Processing Record 14 of Set 3|bani walid
# Processing Record 15 of Set 3|grand gaube
# Processing Record 16 of Set 3|marawi
# Processing Record 17 of Set 3|camacha
# Processing Record 18 of Set 3|pirgos
# Processing Record 19 of Set 3|jamestown
# Processing Record 20 of Set 3|kaka
# Processing Record 21 of Set 3|alofi
# City not found. Skipping...
# Processing Record 22 of Set 3|barrow
# Processing Record 23 of Set 3|lebu
# Processing Record 24 of Set 3|padang
# Processing Record 25 of Set 3|esperance
# City not found. Skipping...
# Processing Record 26 of Set 3|tasiilaq
# Processing Record 27 of Set 3|yuanping
# Processing Record 28 of Set 3|dingle
# Processing Record 29 of Set 3|pauini
# Processing Record 30 of Set 3|price
# City not found. Skipping...
# Processing Record 31 of Set 3|chapais
# Processing Record 32 of Set 3|doha
# Processing Record 33 of Set 3|walvis bay
# Processing Record 34 of Set 3|namatanai
# Processing Record 35 of Set 3|vardo
# Processing Record 36 of Set 3|dikson
# Processing Record 37 of Set 3|bandarbeyla
# Processing Record 38 of Set 3|belmonte
# City not found. Skipping...
# Processing Record 39 of Set 3|hithadhoo
# Processing Record 40 of Set 3|carnarvon
# Processing Record 41 of Set 3|dalvik
# Processing Record 42 of Set 3|olafsvik
# Processing Record 43 of Set 3|boulder
# Processing Record 44 of Set 3|the pas
# Processing Record 45 of Set 3|vila velha
# Processing Record 46 of Set 3|zambezi
# Processing Record 47 of Set 3|ostersund
# Processing Record 48 of Set 3|vila
# Processing Record 49 of Set 3|karatau
# Processing Record 50 of Set 3|zhuzhou
# Processing Record 1 of Set 4|harper
# Processing Record 2 of Set 4|nuuk
# Processing Record 3 of Set 4|aklavik
# Processing Record 4 of Set 4|letlhakeng
# Processing Record 5 of Set 4|alice springs
# Processing Record 6 of Set 4|beringovskiy
# Processing Record 7 of Set 4|bethel
# Processing Record 8 of Set 4|wagga wagga
# Processing Record 9 of Set 4|gedinne
# Processing Record 10 of Set 4|oranjemund
# Processing Record 11 of Set 4|dubna
# Processing Record 12 of Set 4|mashhad
# City not found. Skipping...
# Processing Record 13 of Set 4|mar del plata
# Processing Record 14 of Set 4|taltal
# Processing Record 15 of Set 4|ixtapa
# Processing Record 16 of Set 4|saldanha
# Processing Record 17 of Set 4|lavrentiya
# Processing Record 18 of Set 4|hailey
# Processing Record 19 of Set 4|petropavlovsk-kamchatskiy
# Processing Record 20 of Set 4|arraial do cabo
# Processing Record 21 of Set 4|aitape
# Processing Record 22 of Set 4|preobrazheniye
# Processing Record 23 of Set 4|shingu
# Processing Record 24 of Set 4|pevek
# Processing Record 25 of Set 4|labytnangi
# Processing Record 26 of Set 4|saint-augustin
# Processing Record 27 of Set 4|kruisfontein
# Processing Record 28 of Set 4|alexandria
# Processing Record 29 of Set 4|port hardy
# Processing Record 30 of Set 4|umm lajj
# Processing Record 31 of Set 4|hirara
# City not found. Skipping...
# Processing Record 32 of Set 4|kavieng
# Processing Record 33 of Set 4|souillac
# Processing Record 34 of Set 4|kahului
# Processing Record 35 of Set 4|cherskiy
# Processing Record 36 of Set 4|aksarayskiy
# Processing Record 37 of Set 4|garmsar
# Processing Record 38 of Set 4|norman wells
# Processing Record 39 of Set 4|frontignan
# Processing Record 40 of Set 4|tazovskiy
# Processing Record 41 of Set 4|port lincoln
# City not found. Skipping...
# Processing Record 42 of Set 4|general roca
# Processing Record 43 of Set 4|lata
# City not found. Skipping...
# Processing Record 44 of Set 4|torbay
# City not found. Skipping...
# Processing Record 45 of Set 4|poddorye
# Processing Record 46 of Set 4|provideniya
# Processing Record 47 of Set 4|kirakira
# Processing Record 48 of Set 4|malinovoye ozero
# Processing Record 49 of Set 4|simao
# Processing Record 50 of Set 4|kenora
# Processing Record 1 of Set 5|port keats
# Processing Record 2 of Set 5|bengkulu
# Processing Record 3 of Set 5|puerto colombia
# City not found. Skipping...
# Processing Record 4 of Set 5|bouake
# Processing Record 5 of Set 5|sri aman
# Processing Record 6 of Set 5|ahmadpur sial
# Processing Record 7 of Set 5|ilulissat
# Processing Record 8 of Set 5|faanui
# Processing Record 9 of Set 5|georgetown
# Processing Record 10 of Set 5|mendi
# Processing Record 11 of Set 5|codrington
# Processing Record 12 of Set 5|lagoa
# Processing Record 13 of Set 5|carlsbad
# Processing Record 14 of Set 5|kiunga
# Processing Record 15 of Set 5|birjand
# Processing Record 16 of Set 5|moron
# Processing Record 17 of Set 5|dalbandin
# Processing Record 18 of Set 5|asyut
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 5|ocos
# Processing Record 20 of Set 5|cabo san lucas
# Processing Record 21 of Set 5|izumo
# Processing Record 22 of Set 5|jalu
# Processing Record 23 of Set 5|itarema
# Processing Record 24 of Set 5|airai
# Processing Record 25 of Set 5|nanortalik
# Processing Record 26 of Set 5|cartagena
# Processing Record 27 of Set 5|springfield
# Processing Record 28 of Set 5|havoysund
# Processing Record 29 of Set 5|jabinyanah
# Processing Record 30 of Set 5|beloha
# Processing Record 31 of Set 5|uvinza
# Processing Record 32 of Set 5|panlaitan
# Processing Record 33 of Set 5|luanda
# Processing Record 34 of Set 5|upernavik
# City not found. Skipping...
# Processing Record 35 of Set 5|tsurib
# Processing Record 36 of Set 5|sola
# Processing Record 37 of Set 5|xacmaz
# City not found. Skipping...
# Processing Record 38 of Set 5|kano
# Processing Record 39 of Set 5|qaanaaq
# Processing Record 40 of Set 5|port-gentil
# Processing Record 41 of Set 5|vao
# Processing Record 42 of Set 5|new iberia
# Processing Record 43 of Set 5|long xuyen
# Processing Record 44 of Set 5|kungurtug
# Processing Record 45 of Set 5|astoria
# Processing Record 46 of Set 5|najran
# Processing Record 47 of Set 5|fandriana
# Processing Record 48 of Set 5|mount gambier
# Processing Record 49 of Set 5|fonte boa
# Processing Record 50 of Set 5|grande prairie
# Processing Record 1 of Set 6|valparaiso
# City not found. Skipping...
# Processing Record 2 of Set 6|chara
# Processing Record 3 of Set 6|chakulia
# Processing Record 4 of Set 6|yenagoa
# Processing Record 5 of Set 6|zwedru
# Processing Record 6 of Set 6|hobyo
# Processing Record 7 of Set 6|cidreira
# Processing Record 8 of Set 6|myaundzha
# Processing Record 9 of Set 6|hambantota
# Processing Record 10 of Set 6|kaduna
# Processing Record 11 of Set 6|rawson
# Processing Record 12 of Set 6|luzhou
# Processing Record 13 of Set 6|te anau
# City not found. Skipping...
# Processing Record 14 of Set 6|sitka
# Processing Record 15 of Set 6|polyarnyy
# Processing Record 16 of Set 6|nirmal
# Processing Record 17 of Set 6|ivanteyevka
# Processing Record 18 of Set 6|paamiut
# Processing Record 19 of Set 6|mata
# Processing Record 20 of Set 6|kankan
# Processing Record 21 of Set 6|havre-saint-pierre
# Processing Record 22 of Set 6|saint george
# Processing Record 23 of Set 6|nueva concepcion
# Processing Record 24 of Set 6|knesselare
# Processing Record 25 of Set 6|borovoy
# City not found. Skipping...
# Processing Record 26 of Set 6|yerbogachen
# Processing Record 27 of Set 6|rocklin
# City not found. Skipping...
# Processing Record 28 of Set 6|shubarkuduk
# Processing Record 29 of Set 6|didi lilo
# Processing Record 30 of Set 6|tucumcari
# Processing Record 31 of Set 6|sao gabriel
# Processing Record 32 of Set 6|ikwiriri
# Processing Record 33 of Set 6|livramento
# Processing Record 34 of Set 6|neftcala
# Processing Record 35 of Set 6|jiuquan
# Processing Record 36 of Set 6|terre-de-bas
# Processing Record 37 of Set 6|kalianget
# Processing Record 38 of Set 6|plomarion
# Processing Record 39 of Set 6|paoua
# Processing Record 40 of Set 6|kedrovyy
# Processing Record 41 of Set 6|klaksvik
# Processing Record 42 of Set 6|pailon
# Processing Record 43 of Set 6|juneau
# Processing Record 44 of Set 6|marigot
# Processing Record 45 of Set 6|shahpura
# Processing Record 46 of Set 6|varhaug
# City not found. Skipping...
# Processing Record 47 of Set 6|akyab
# Processing Record 48 of Set 6|victoria
# Processing Record 49 of Set 6|celestun
# Processing Record 50 of Set 6|nome
# Processing Record 1 of Set 7|morondava
# Processing Record 2 of Set 7|batemans bay
# Processing Record 3 of Set 7|iquitos
# Processing Record 4 of Set 7|dongsheng
# Processing Record 5 of Set 7|veraval
# Processing Record 6 of Set 7|mayumba
# Processing Record 7 of Set 7|nyurba
# Processing Record 8 of Set 7|ginir
# Processing Record 9 of Set 7|zemio
# Processing Record 10 of Set 7|ahipara
# Processing Record 11 of Set 7|zilair
# Processing Record 12 of Set 7|mae hong son
# Processing Record 13 of Set 7|tanout
# Processing Record 14 of Set 7|nouadhibou
# Processing Record 15 of Set 7|tura
# Processing Record 16 of Set 7|ribnitz-damgarten
# Processing Record 17 of Set 7|fayaoue
# Processing Record 18 of Set 7|santa cruz
# Processing Record 19 of Set 7|svetlaya
# Processing Record 20 of Set 7|kumylzhenskaya
# Processing Record 21 of Set 7|santona
# Processing Record 22 of Set 7|henderson
# Processing Record 23 of Set 7|mahon
# Processing Record 24 of Set 7|taoudenni
# Processing Record 25 of Set 7|anjozorobe
# Processing Record 26 of Set 7|martapura
# Processing Record 27 of Set 7|bilibino
# Processing Record 28 of Set 7|liverpool
# Processing Record 29 of Set 7|kozhevnikovo
# Processing Record 30 of Set 7|santa marta
# Processing Record 31 of Set 7|koutiala
# Processing Record 32 of Set 7|tobane
# Processing Record 33 of Set 7|aurora
# Processing Record 34 of Set 7|wonthaggi
# Processing Record 35 of Set 7|hope
# Processing Record 36 of Set 7|lianzhou
# Processing Record 37 of Set 7|bani
# Processing Record 38 of Set 7|oistins
# Processing Record 39 of Set 7|harnosand
# Processing Record 40 of Set 7|guerrero negro
# Processing Record 41 of Set 7|shenjiamen
# Processing Record 42 of Set 7|leningradskiy
# Processing Record 43 of Set 7|sorland
# Processing Record 44 of Set 7|flinders
# Processing Record 45 of Set 7|mnogovershinnyy
# Processing Record 46 of Set 7|sao filipe
# Processing Record 47 of Set 7|urumqi
# Processing Record 48 of Set 7|boralday
# Processing Record 49 of Set 7|manati
# Processing Record 50 of Set 7|srisailam
# City not found. Skipping...
# Processing Record 1 of Set 8|sturgis
# Processing Record 2 of Set 8|opole lubelskie
# Processing Record 3 of Set 8|weinan
# Processing Record 4 of Set 8|kulhudhuffushi
# Processing Record 5 of Set 8|fort smith
# Processing Record 6 of Set 8|ariquemes
# Processing Record 7 of Set 8|touros
# Processing Record 8 of Set 8|sur
# Processing Record 9 of Set 8|laguna
# Processing Record 10 of Set 8|maues
# Processing Record 11 of Set 8|ust-nera
# Processing Record 12 of Set 8|hamilton
# Processing Record 13 of Set 8|turinsk
# Processing Record 14 of Set 8|manpur
# Processing Record 15 of Set 8|vavuniya
# Processing Record 16 of Set 8|constantine
# Processing Record 17 of Set 8|bambous virieux
# Processing Record 18 of Set 8|funtua
# Processing Record 19 of Set 8|iracoubo
# Processing Record 20 of Set 8|houlton
# City not found. Skipping...
# Processing Record 21 of Set 8|atar
# Processing Record 22 of Set 8|along
# Processing Record 23 of Set 8|makakilo city
# City not found. Skipping...
# Processing Record 24 of Set 8|markova
# Processing Record 25 of Set 8|liusha
# Processing Record 26 of Set 8|saint-joseph
# Processing Record 27 of Set 8|sidney
# Processing Record 28 of Set 8|bonavista
# Processing Record 29 of Set 8|odweyne
# Processing Record 30 of Set 8|mareeba
# Processing Record 31 of Set 8|ballina
# Processing Record 32 of Set 8|nizhniy kuranakh
# City not found. Skipping...
# Processing Record 33 of Set 8|am timan
# Processing Record 34 of Set 8|rafaela
# Processing Record 35 of Set 8|cabedelo
# Processing Record 36 of Set 8|ambulu
# Processing Record 37 of Set 8|caravelas
# Processing Record 38 of Set 8|raudeberg
# Processing Record 39 of Set 8|kishtwar
# Processing Record 40 of Set 8|tucuma
# Processing Record 41 of Set 8|tautira
# Processing Record 42 of Set 8|ambovombe
# Processing Record 43 of Set 8|nyalikungu
# Processing Record 44 of Set 8|khandyga
# Processing Record 45 of Set 8|aasiaat
# Processing Record 46 of Set 8|tilichiki
# City not found. Skipping...
# Processing Record 47 of Set 8|salalah
# Processing Record 48 of Set 8|vanimo
# Processing Record 49 of Set 8|kaga
# Processing Record 50 of Set 8|vostok
# Processing Record 1 of Set 9|mount isa
# Processing Record 2 of Set 9|tezu
# Processing Record 3 of Set 9|fort nelson
# Processing Record 4 of Set 9|lipin bor
# Processing Record 5 of Set 9|kilindoni
# City not found. Skipping...
# Processing Record 6 of Set 9|balkhash
# Processing Record 7 of Set 9|ayan
# Processing Record 8 of Set 9|broome
# Processing Record 9 of Set 9|hameenlinna
# Processing Record 10 of Set 9|bulawayo
# Processing Record 11 of Set 9|puerto quijarro
# Processing Record 12 of Set 9|douentza
# Processing Record 13 of Set 9|barranca
# Processing Record 14 of Set 9|deputatskiy
# Processing Record 15 of Set 9|nkhata bay
# Processing Record 16 of Set 9|trapani
# Processing Record 17 of Set 9|campoverde
# Processing Record 18 of Set 9|buta
# Processing Record 19 of Set 9|zhezkazgan
# Processing Record 20 of Set 9|hualmay
# Processing Record 21 of Set 9|dwarka
# Processing Record 22 of Set 9|sabla
# Processing Record 23 of Set 9|okhotsk
# Processing Record 24 of Set 9|talnakh
# City not found. Skipping...
# Processing Record 25 of Set 9|lisala
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 9|montepuez
# Processing Record 27 of Set 9|dryden
# City not found. Skipping...
# Processing Record 28 of Set 9|sechura
# Processing Record 29 of Set 9|bundaberg
# Processing Record 30 of Set 9|port elizabeth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 9|coihaique
# Processing Record 32 of Set 9|marsh harbour
# Processing Record 33 of Set 9|umea
# Processing Record 34 of Set 9|ziarat
# Processing Record 35 of Set 9|los andes
# Processing Record 36 of Set 9|corinth
# Processing Record 37 of Set 9|flin flon
# Processing Record 38 of Set 9|lac du bonnet
# Processing Record 39 of Set 9|norrtalje
# Processing Record 40 of Set 9|srednekolymsk
# Processing Record 41 of Set 9|saint-georges
# Processing Record 42 of Set 9|mastung
# Processing Record 43 of Set 9|mehamn
# City not found. Skipping...
# Processing Record 44 of Set 9|jalingo
# City not found. Skipping...
# Processing Record 45 of Set 9|shakawe
# Processing Record 46 of Set 9|manavalakurichi
# Processing Record 47 of Set 9|richards bay
# Processing Record 48 of Set 9|novo cruzeiro
# Processing Record 49 of Set 9|safonovo
# Processing Record 50 of Set 9|bata
# City not found. Skipping...
# Processing Record 1 of Set 10|champerico
# Processing Record 2 of Set 10|markdale
# Processing Record 3 of Set 10|konyshevka
# Processing Record 4 of Set 10|xining
# Processing Record 5 of Set 10|lorengau
# Processing Record 6 of Set 10|elwood
# Processing Record 7 of Set 10|dhidhdhoo
# Processing Record 8 of Set 10|barra do corda
# Processing Record 9 of Set 10|tabuk
# Processing Record 10 of Set 10|yaan
# Processing Record 11 of Set 10|lompoc
# Processing Record 12 of Set 10|kirillov
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 10|chaves
# Processing Record 14 of Set 10|saskylakh
# Processing Record 15 of Set 10|mackay
# Processing Record 16 of Set 10|paragominas
# Processing Record 17 of Set 10|sistranda
# Processing Record 18 of Set 10|beira
# Processing Record 19 of Set 10|sortland
# Processing Record 20 of Set 10|port blair
# Processing Record 21 of Set 10|nishihara
# Processing Record 22 of Set 10|kupang
# Processing Record 23 of Set 10|eyl
# Processing Record 24 of Set 10|oriximina
# Processing Record 25 of Set 10|montijo
# Processing Record 26 of Set 10|chuy
# Processing Record 27 of Set 10|ekhabi
# Processing Record 28 of Set 10|hede
# Processing Record 29 of Set 10|changji
# Processing Record 30 of Set 10|tonantins
# Processing Record 31 of Set 10|nicoya
# Processing Record 32 of Set 10|robertsport
# Processing Record 33 of Set 10|pirmasens
# Processing Record 34 of Set 10|santa fe
# Processing Record 35 of Set 10|riyadh
# Processing Record 36 of Set 10|ati
# Processing Record 37 of Set 10|prokuplje
# Processing Record 38 of Set 10|tessalit
# City not found. Skipping...
# Processing Record 39 of Set 10|korla
# Processing Record 40 of Set 10|christchurch
# Processing Record 41 of Set 10|san patricio
# Processing Record 42 of Set 10|progreso
# Processing Record 43 of Set 10|gorom-gorom
# Processing Record 44 of Set 10|north bend
# Processing Record 45 of Set 10|nerchinskiy zavod
# Processing Record 46 of Set 10|ranau
# Processing Record 47 of Set 10|alghero
# Processing Record 48 of Set 10|lazaro cardenas
# Processing Record 49 of Set 10|san carlos de bariloche
# Processing Record 50 of Set 10|coahuayana
# Processing Record 1 of Set 11|luderitz
# Processing Record 2 of Set 11|bakchar
# Processing Record 3 of Set 11|axim
# Processing Record 4 of Set 11|zarinsk
# Processing Record 5 of Set 11|roseau
# Processing Record 6 of Set 11|ardakan
# Processing Record 7 of Set 11|ceres
# Processing Record 8 of Set 11|qui nhon
# Processing Record 9 of Set 11|bilokurakyne
# Processing Record 10 of Set 11|azangaro
# Processing Record 11 of Set 11|zyryanka
# Processing Record 12 of Set 11|kieta
# Processing Record 13 of Set 11|imbituba
# Processing Record 14 of Set 11|wenling
# Processing Record 15 of Set 11|tutoia
# Processing Record 16 of Set 11|kangaatsiaq
# Processing Record 17 of Set 11|aguimes
# Processing Record 18 of Set 11|cochrane
# Processing Record 19 of Set 11|port hedland
# Processing Record 20 of Set 11|kendari
# Processing Record 21 of Set 11|talara
# Processing Record 22 of Set 11|urubicha
# Processing Record 23 of Set 11|mao
# Processing Record 24 of Set 11|durango
# Processing Record 25 of Set 11|poplar bluff
# City not found. Skipping...
# Processing Record 26 of Set 11|ciudad bolivar
# Processing Record 27 of Set 11|sunel
# City not found. Skipping...
# Processing Record 28 of Set 11|pervoye maya
# Processing Record 29 of Set 11|nizwa
# Processing Record 30 of Set 11|nacozari
# Processing Record 31 of Set 11|mwinilunga
# Processing Record 32 of Set 11|northam
# Processing Record 33 of Set 11|bichura
# Processing Record 34 of Set 11|baiyin
# Processing Record 35 of Set 11|tuatapere
# Processing Record 36 of Set 11|mazagao
# Processing Record 37 of Set 11|saint anthony
# Processing Record 38 of Set 11|bac lieu
# Processing Record 39 of Set 11|semey
# Processing Record 40 of Set 11|newport
# Processing Record 41 of Set 11|newcastle
# Processing Record 42 of Set 11|miri
# Processing Record 43 of Set 11|chicama
# Processing Record 44 of Set 11|salamiyah
# Processing Record 45 of Set 11|dukat
# Processing Record 46 of Set 11|samarai
# Processing Record 47 of Set 11|dakar
# Processing Record 48 of Set 11|sungurlu
# Processing Record 49 of Set 11|sailana
# Processing Record 50 of Set 11|ketchikan
# Processing Record 1 of Set 12|mungwi
# Processing Record 2 of Set 12|ponta delgada
# Processing Record 3 of Set 12|elban
# City not found. Skipping...
# ------------------------
# -Data Retrieval Complete
# ------------------------

# %% [markdown]
# # Convert Raw Data to DataFrame

# %%
#Display the dataframe
city_df = pd.DataFrame(city_df)
city_df
# Out:
#                City Country      Lat       Lng  Max Temp  Wind Speed  \
# 0    ribeira grande      PT  38.5167  -28.7000     62.60       16.11
# 1           gunupur      IN  19.0833   83.8167     76.96        0.34
# 2           rikitea      PF -23.1203 -134.9692     75.67        8.52
# 3           isangel      VU -19.5500  169.2667     78.80        9.22
# 4         geraldton      AU -28.7667  114.6000     50.00        6.91
# ..              ...     ...      ...       ...       ...         ...
# 548         sailana      IN  23.4667   74.9167     80.92        7.14
# 549       ketchikan      US  55.3422 -131.6461     46.60        3.29
# 550          mungwi      ZM -10.1732   31.3694     61.86        3.91
# 551   ponta delgada      PT  37.7333  -25.6667     59.00       14.97
# 552           elban      RU  50.1018  136.5094     43.84       13.18
#
#      Cloudiness  Humidity        Date
# 0            75        94  1619912238
# 1             2        83  1619912517
# 2            93        80  1619911979
# 3            90        78  1619912520
# 4            72        66  1619912521
# ..          ...       ...         ...
# 548          93        34  1619913321
# 549          96        91  1619913322
# 550          95        96  1619913323
# 551          75       100  1619913325
# 552         100        55  1619913326
#
# [553 rows x 9 columns]

# %%
# Export the city data into a .csv.
city_df.to_csv('output_data_cities.csv', encoding='utf-8',index=False)

# %% [markdown]
# # Inspect the data and remove the cities where the humidity >%100

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_over = city_df[city_df['Humidity'] > 100]
                        
humidity_over
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Wind Speed, Cloudiness, Humidity, Date]
# Index: []

# %% [markdown]
# # Plotting the Data

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.

# %%
# Plot
plt.scatter(city_df['Lat'], city_df['Max Temp'], edgecolors='black')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature')
plt.grid(color='grey', linestyle='-', linewidth=1)
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
# Plot
plt.scatter(city_df['Lat'], city_df['Humidity'], edgecolors='black')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs. Humidity')
plt.grid(color='grey', linestyle='-', linewidth=1)
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
# Plot
plt.scatter(city_df['Lat'], city_df['Cloudiness'], edgecolors='black')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness')
plt.grid(color='grey', linestyle='-', linewidth=1)
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Plot
plt.scatter(city_df['Lat'], city_df['Wind Speed'], edgecolors='black')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs. Wind Speed')
plt.grid(color='grey', linestyle='-', linewidth=1)
plt.show()

# %% [markdown]
# # Linear Regression

# %%
northern_hemisphere = city_df[city_df['Lat'] >= 0]

southern_hemisphere = city_df[city_df['Lat'] < 0]

southern_hemisphere
# Out:
#           City Country      Lat       Lng  Max Temp  Wind Speed  Cloudiness  \
# 2      rikitea      PF -23.1203 -134.9692     75.67        8.52          93
# 3      isangel      VU -19.5500  169.2667     78.80        9.22          90
# 4    geraldton      AU -28.7667  114.6000     50.00        6.91          72
# 6        bluff      NZ -46.6000  168.3333     55.99        5.99          60
# 7       atuona      PF  -9.8000 -139.0333     79.39        6.82           2
# ..         ...     ...      ...       ...       ...         ...         ...
# 535    mazagao      BR  -0.1150  -51.2894     77.00        3.44          20
# 540  newcastle      AU -32.9272  151.7765     69.80        6.91          92
# 542    chicama      PE  -7.8447  -79.1469     64.40        9.22          40
# 545    samarai      PG -10.6167  150.6667     81.09        9.75          34
# 550     mungwi      ZM -10.1732   31.3694     61.86        3.91          95
#
#      Humidity        Date
# 2          80  1619911979
# 3          78  1619912520
# 4          66  1619912521
# 6          76  1619912233
# 7          68  1619912238
# ..        ...         ...
# 535       100  1619913303
# 540        73  1619913310
# 542        94  1619913313
# 545        78  1619913098
# 550        96  1619913323
#
# [172 rows x 9 columns]

# %% [markdown]
# ## Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (F)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.801431527634622

# %% [markdown]
# ## Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,40),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (F)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.48178896865977894

# %% [markdown]
# ## Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,7),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (%)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.02822026622678243

# %% [markdown]
# ## Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(-55,40),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (%)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.08403817327650202

# %% [markdown]
# ## Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(45,45),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (%)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.019039943431484994

# %% [markdown]
# ## Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (%)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.06229801625014593

# %% [markdown]
# ## Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(6,25),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph')
plt.title('City Latitude vs. Wind Speed (mph)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.003707180365191901

# %% [markdown]
# ## Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Print out the r-squared value along with the plot.
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(-50,20),fontsize=15,color='red')

# Format scatter plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (mph)')
print(f'The r-squared is: {rvalue**2}')
plt.show()
# Out:
# The r-squared is: 0.05979967422284994

# %% [markdown]
# # Observable Trends
#
# While temperature had a high correlation to distance from the equator humidity, cloudiness, and wind speed were more evenly distributed regardless of equator location.
#
# There are significantly more data points to study in the northern hemisphere as opposed to the southern hemisphere.
#
# Very few cities with negative lattitudes had a humidity percentage below 40%.  Lattitudes above 0 were much more likely to have a lower humidity percentage.
